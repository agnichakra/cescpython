# %%
import pandas as pd
df = pd.read_csv("samplecsv.csv")
df
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %% [raw]
# emp = {"empid" :4466}
#
# df = DataFrame(emp)

# %%
df.shape
# Out:
# (700, 16)

# %%
r,c = df.shape
print(r)
# Out:
# 700

# %%
df.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold  \
# 0  Government   Canada   Carretera            None       1618.5
# 1  Government  Germany   Carretera            None       1321.0
# 2   Midmarket   France   Carretera            None       2178.0
# 3   Midmarket  Germany   Carretera            None        888.0
# 4   Midmarket   Mexico   Carretera            None       2470.0
#
#     Manufacturing Price    Sale Price   Gross Sales   Discounts      Sales   \
# 0                      3            20     32,370.00        -     32,370.00
# 1                      3            20     26,420.00        -     26,420.00
# 2                      3            15     32,670.00        -     32,670.00
# 3                      3            15     13,320.00        -     13,320.00
# 4                      3            15     37,050.00        -     37,050.00
#
#        COGS     Profit         Date  Month Number  Month Name   Year
# ...

# %%
df.head(8)
# Out:
#             Segment  Country     Product   Discount Band   Units Sold  \
# 0        Government   Canada   Carretera            None       1618.5
# 1        Government  Germany   Carretera            None       1321.0
# 2         Midmarket   France   Carretera            None       2178.0
# 3         Midmarket  Germany   Carretera            None        888.0
# 4         Midmarket   Mexico   Carretera            None       2470.0
# 5        Government  Germany   Carretera            None       1513.0
# 6         Midmarket  Germany     Montana            None        921.0
# 7  Channel Partners   Canada     Montana            None       2518.0
#
#     Manufacturing Price    Sale Price   Gross Sales   Discounts        Sales   \
# 0                      3            20     32,370.00        -       32,370.00
# 1                      3            20     26,420.00        -       26,420.00
# 2                      3            15     32,670.00        -       32,670.00
# ...

# %%
df.tail()
# Out:
#               Segment                   Country    Product   Discount Band   \
# 695    Small Business                    France   Amarilla            High
# 696    Small Business                    Mexico   Amarilla            High
# 697        Government                    Mexico    Montana            High
# 698        Government                    Canada      Paseo            High
# 699  Channel Partners  United States of America        VTT            High
#
#      Units Sold   Manufacturing Price    Sale Price   Gross Sales   \
# 695      2475.0                    260           300   7,42,500.00
# 696       546.0                    260           300   1,63,800.00
# 697      1368.0                      5             7      9,576.00
# 698       723.0                     10             7      5,061.00
# 699      1806.0                    250            12     21,672.00
#
#       Discounts        Sales         COGS     Profit         Date  \
# ...

# %%
df[6:80]
# Out:
#              Segment                   Country   Product   Discount Band   \
# 6          Midmarket                   Germany   Montana            None
# 7   Channel Partners                    Canada   Montana            None
# 8         Government                    France   Montana            None
# 9   Channel Partners                   Germany   Montana            None
# 10         Midmarket                    Mexico   Montana            None
# ..               ...                       ...        ...             ...
# 75        Government  United States of America     Paseo             Low
# 76        Enterprise  United States of America     Paseo             Low
# 77        Enterprise                    France     Paseo             Low
# 78        Enterprise                    Mexico     Paseo             Low
# 79         Midmarket                   Germany     Paseo             Low
#
#     Units Sold   Manufacturing Price    Sale Price   Gross Sales   Discounts   \
# ...

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', 'Units Sold',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df[' Gross Sales '].max()
# Out:
# '99,375.00'

# %%
df[' Gross Sales '].min()
# Out:
# '1,00,200.00'
